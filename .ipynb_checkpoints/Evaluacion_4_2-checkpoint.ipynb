# %% [markdown]
# # Evaluación 4

# %% [markdown]
# ## Tarea 5
#
# Get a polygons map of the lowest administrative unit possible.
#
# Get a table of variables for those units. At least 3 numerical variables.
#
# Preprocess both tables and get them ready for merging.
#
# Do the merging, making the changes needed so that you keep the most columns.

# %%
# En este caso, se consiguieron los mapas para los distritos, pero no se encontraron datos para cada distrito. En este sentido,
# solo quedó trabajar con las provincias. La República Democrática del Congo publicó el 2020 un anuario con muchos datos, pero
# estos casi completamente en función de las provincias. Se decidió trabajar con estos datos. 
# fuente de los datos: https://ins.cd/wp-content/uploads/2022/06/ANNUAIRE-STATISTIQUE-2020.pdf
# Estos datos estaban en pdf, así que se tuvieron que copiar manualmente a un archivo de excel

# %%
# Se definen las provincias a partir de una shape file
import os
import pandas as pd 
import geopandas as gpd

Provincias_DRC = gpd.read_file(os.path.join("data","provincias_DRC","cod_admbnda_adm1_rgc_itos_20190911.shp"))
Provincias_DRC
# Out:
#     Shape_Leng  Shape_Area         ADM1_FR ADM1_PCODE        ADM1_REF  \
# 0    24.837413   12.097933        Bas-Uele       CD52            None
# 1    20.947731    8.291592        Equateur       CD41            None
# 2    29.557091   10.316791    Haut-Katanga       CD71            None
# 3    20.855157    8.952551     Haut-Lomami       CD73            None
# 4    21.679976    7.433290       Haut-Uele       CD53            None
# 5    17.849736    5.280520           Ituri       CD54            None
# 6    18.559369    7.887821           Kasaï       CD92           Kasai
# 7    14.745456    4.664225   Kasaï-Central       CD91   Kasai-Central
# 8     5.475921    0.833257  Kasaï-Oriental       CD82  Kasai-Oriental
# 9     5.604623    0.864438        Kinshasa       CD10            None
# 10   13.876726    4.402665   Kongo-Central       CD20            None
# 11   19.157190    7.352973          Kwango       CD31            None
# 12   16.848822    6.455370           Kwilu       CD32            None
# 13   16.305692    4.410003          Lomami       CD81            None
# 14   25.112956   10.038531         Lualaba       CD72            None
# 15   18.785376   10.450487      Maï-Ndombe       CD33      Mai-Ndombe
# 16   24.827430   10.383610         Maniema       CD63            None
# 17   17.154945    4.566610         Mongala       CD44            None
# 18   13.427228    4.790481       Nord-Kivu       CD61            None
# 19   14.722594    4.413101     Nord-Ubangi       CD43            None
# 20   17.636984    8.810696         Sankuru       CD83            None
# 21   14.423616    5.226450        Sud-Kivu       CD62            None
# 22   12.618229    4.234287      Sud-Ubangi       CD42            None
# 23   19.842214   10.846440      Tanganyika       CD74            None
# 24   26.602167   16.290309          Tshopo       CD51            None
# 25   23.911970   10.801180         Tshuapa       CD45            None
#
#    ADM1ALT1FR ADM1ALT2FR                                ADM0_FR ADM0_PCODE  \
# 0        None       None  République démocratique du Congo (la)         CD
# 1        None       None  République démocratique du Congo (la)         CD
# 2        None       None  République démocratique du Congo (la)         CD
# 3        None       None  République démocratique du Congo (la)         CD
# 4        None       None  République démocratique du Congo (la)         CD
# 5        None       None  République démocratique du Congo (la)         CD
# 6        None       None  République démocratique du Congo (la)         CD
# 7        None       None  République démocratique du Congo (la)         CD
# 8        None       None  République démocratique du Congo (la)         CD
# 9        None       None  République démocratique du Congo (la)         CD
# 10       None       None  République démocratique du Congo (la)         CD
# 11       None       None  République démocratique du Congo (la)         CD
# 12       None       None  République démocratique du Congo (la)         CD
# 13       None       None  République démocratique du Congo (la)         CD
# 14       None       None  République démocratique du Congo (la)         CD
# 15       None       None  République démocratique du Congo (la)         CD
# 16       None       None  République démocratique du Congo (la)         CD
# 17       None       None  République démocratique du Congo (la)         CD
# 18       None       None  République démocratique du Congo (la)         CD
# 19       None       None  République démocratique du Congo (la)         CD
# 20       None       None  République démocratique du Congo (la)         CD
# 21       None       None  République démocratique du Congo (la)         CD
# 22       None       None  République démocratique du Congo (la)         CD
# 23       None       None  République démocratique du Congo (la)         CD
# 24       None       None  République démocratique du Congo (la)         CD
# 25       None       None  République démocratique du Congo (la)         CD
#
#           date     validOn validTo  \
# 0   2019-09-09  2019-09-11    None
# 1   2019-09-09  2019-09-11    None
# 2   2019-09-09  2019-09-11    None
# 3   2019-09-09  2019-09-11    None
# 4   2019-09-09  2019-09-11    None
# 5   2019-09-09  2019-09-11    None
# 6   2019-09-09  2019-09-11    None
# 7   2019-09-09  2019-09-11    None
# 8   2019-09-09  2019-09-11    None
# 9   2019-09-09  2019-09-11    None
# 10  2019-09-09  2019-09-11    None
# 11  2019-09-09  2019-09-11    None
# 12  2019-09-09  2019-09-11    None
# 13  2019-09-09  2019-09-11    None
# 14  2019-09-09  2019-09-11    None
# 15  2019-09-09  2019-09-11    None
# 16  2019-09-09  2019-09-11    None
# 17  2019-09-09  2019-09-11    None
# 18  2019-09-09  2019-09-11    None
# 19  2019-09-09  2019-09-11    None
# 20  2019-09-09  2019-09-11    None
# 21  2019-09-09  2019-09-11    None
# 22  2019-09-09  2019-09-11    None
# 23  2019-09-09  2019-09-11    None
# 24  2019-09-09  2019-09-11    None
# 25  2019-09-09  2019-09-11    None
#
#                                              geometry
# 0   POLYGON ((25.55505 5.37646, 25.56033 5.37533, ...
# 1   POLYGON ((19.51188 2.02196, 19.60032 2.00518, ...
# 2   POLYGON ((28.54810 -7.62268, 28.56232 -7.63546...
# 3   POLYGON ((25.94890 -6.23409, 25.94897 -6.24754...
# 4   POLYGON ((27.39413 5.09610, 27.41456 5.08784, ...
# 5   POLYGON ((30.78596 3.64700, 30.78596 3.62100, ...
# 6   POLYGON ((21.75535 -2.49128, 21.76883 -2.49800...
# 7   POLYGON ((22.91916 -4.52640, 22.94181 -4.52706...
# 8   POLYGON ((23.73511 -5.68923, 23.73781 -5.69317...
# 9   POLYGON ((15.95045 -3.93047, 15.95131 -3.93136...
# 10  POLYGON ((14.41276 -4.31460, 14.41882 -4.32696...
# 11  POLYGON ((17.61221 -4.23314, 17.62396 -4.24320...
# 12  POLYGON ((17.39747 -3.19806, 17.40001 -3.20150...
# 13  POLYGON ((25.00325 -4.86532, 25.00509 -4.86703...
# 14  POLYGON ((21.96284 -7.69976, 21.97001 -7.70335...
# 15  POLYGON ((19.15473 -0.82204, 19.16991 -0.85066...
# 16  POLYGON ((26.07762 -0.03658, 26.07949 -0.03686...
# 17  POLYGON ((22.71572 3.12765, 22.72612 3.11883, ...
# 18  POLYGON ((29.86257 0.95052, 29.86276 0.93075, ...
# 19  POLYGON ((19.60200 5.13200, 19.61300 5.12800, ...
# 20  POLYGON ((23.99545 -1.70136, 23.99908 -1.70323...
# 21  POLYGON ((29.05073 -1.58385, 29.05140 -1.58395...
# 22  POLYGON ((19.07291 4.77567, 19.07509 4.77141, ...
# 23  POLYGON ((26.96836 -4.99952, 27.08852 -5.00293...
# 24  POLYGON ((23.59908 2.20184, 23.59396 2.19113, ...
# 25  POLYGON ((22.12739 1.76262, 22.15742 1.76226, ...

# %%
# Ahora, se leen los datos que se obtuvieron
Estadisticas_DRC = pd.read_excel(os.path.join('data', 'Estad.xlsx'))
Estadisticas_DRC
# Out:
#          Provincia  Esperanza de vida  Años de escolarización  \
# 0         Kinshasa               64.6                    13.7
# 1    Kongo Central               67.7                    11.3
# 2       Maï-Ndombe               56.6                    11.8
# 3            Kwilu               63.4                    13.3
# 4           Kwango               51.5                    10.7
# 5         Equateur               61.2                    10.8
# 6       Sud-Ubangi               51.6                    10.5
# 7      Nord-Ubangi               57.7                    12.5
# 8          Mongala               56.0                     8.4
# 9          Tshuapa               48.6                    10.6
# 10          Tshopo               60.3                    11.3
# 11        Bas-Uele               56.1                     9.9
# 12       Haut-Uele               50.5                     8.5
# 13           Ituri               58.7                     6.8
# 14       Nord Kivu               59.5                    11.2
# 15        Sud Kivu               62.5                     9.2
# 16         Maniema               52.0                    11.8
# 17         Lualaba               58.2                     8.4
# 18     Haut-Lomami               53.9                     8.5
# 19      Tanganyika               53.4                     8.5
# 20    Haut-Katanga               56.7                    12.4
# 21  Kasaï Oriental               50.6                     9.5
# 22         Sankuru               51.0                    11.9
# 23          Lomami               61.8                    11.3
# 24           Kasaï               56.8                     9.4
# 25   Kasaï Central               53.3                    11.7
#
#     Número promedio de años de escolarización en adultos  \
# 0                                                11.2
# 1                                                 7.5
# 2                                                 6.8
# 3                                                 8.4
# 4                                                 5.2
# 5                                                 7.6
# 6                                                 5.2
# 7                                                 5.8
# 8                                                 5.4
# 9                                                 5.6
# 10                                                7.2
# 11                                                5.2
# 12                                                5.8
# 13                                                3.5
# 14                                                8.4
# 15                                                7.6
# 16                                                6.4
# 17                                                5.8
# 18                                                5.8
# 19                                                5.3
# 20                                               10.0
# 21                                                6.9
# 22                                                6.8
# 23                                                6.3
# 24                                                6.1
# 25                                                6.8
#
#     Tasa de desempleo 2016
# 0                     11.4
# 1                      2.0
# 2                      0.7
# 3                      2.1
# 4                      0.4
# 5                      1.3
# 6                      0.3
# 7                      0.6
# 8                      0.1
# 9                      0.6
# 10                     0.9
# 11                     0.3
# 12                     3.2
# 13                     1.7
# 14                     8.2
# 15                     2.7
# 16                     1.8
# 17                     1.3
# 18                     2.3
# 19                     0.9
# 20                    11.1
# 21                     2.0
# 22                     2.1
# 23                     0.5
# 24                     0.1
# 25                     2.0

# %%
# Hay datos irrelevantes, así que se procesan los data frame para que quede solo lo útil

# %%
# La tabla con los datos está bastan bien, así que se deja así, pero igual se pueden cambiar los espacios de los nombres de las
# columnas
Estadisticas_DRC.columns = Estadisticas_DRC.columns.str.replace(' ', '_')

# %%
# La gdf con los distritos sí tiene algunas columnas innecesarias

P_DRC = Provincias_DRC.loc[:,['ADM1_FR','geometry']]

#Finalmente, también se puede cambiar el nombre de la columna a provincias
P_DRC = P_DRC.rename(columns={'ADM1_FR': 'Provincia'})
P_DRC
# Out:
#          Provincia                                           geometry
# 0         Bas-Uele  POLYGON ((25.55505 5.37646, 25.56033 5.37533, ...
# 1         Equateur  POLYGON ((19.51188 2.02196, 19.60032 2.00518, ...
# 2     Haut-Katanga  POLYGON ((28.54810 -7.62268, 28.56232 -7.63546...
# 3      Haut-Lomami  POLYGON ((25.94890 -6.23409, 25.94897 -6.24754...
# 4        Haut-Uele  POLYGON ((27.39413 5.09610, 27.41456 5.08784, ...
# 5            Ituri  POLYGON ((30.78596 3.64700, 30.78596 3.62100, ...
# 6            Kasaï  POLYGON ((21.75535 -2.49128, 21.76883 -2.49800...
# 7    Kasaï-Central  POLYGON ((22.91916 -4.52640, 22.94181 -4.52706...
# 8   Kasaï-Oriental  POLYGON ((23.73511 -5.68923, 23.73781 -5.69317...
# 9         Kinshasa  POLYGON ((15.95045 -3.93047, 15.95131 -3.93136...
# 10   Kongo-Central  POLYGON ((14.41276 -4.31460, 14.41882 -4.32696...
# 11          Kwango  POLYGON ((17.61221 -4.23314, 17.62396 -4.24320...
# 12           Kwilu  POLYGON ((17.39747 -3.19806, 17.40001 -3.20150...
# 13          Lomami  POLYGON ((25.00325 -4.86532, 25.00509 -4.86703...
# 14         Lualaba  POLYGON ((21.96284 -7.69976, 21.97001 -7.70335...
# 15      Maï-Ndombe  POLYGON ((19.15473 -0.82204, 19.16991 -0.85066...
# 16         Maniema  POLYGON ((26.07762 -0.03658, 26.07949 -0.03686...
# 17         Mongala  POLYGON ((22.71572 3.12765, 22.72612 3.11883, ...
# 18       Nord-Kivu  POLYGON ((29.86257 0.95052, 29.86276 0.93075, ...
# 19     Nord-Ubangi  POLYGON ((19.60200 5.13200, 19.61300 5.12800, ...
# 20         Sankuru  POLYGON ((23.99545 -1.70136, 23.99908 -1.70323...
# 21        Sud-Kivu  POLYGON ((29.05073 -1.58385, 29.05140 -1.58395...
# 22      Sud-Ubangi  POLYGON ((19.07291 4.77567, 19.07509 4.77141, ...
# 23      Tanganyika  POLYGON ((26.96836 -4.99952, 27.08852 -5.00293...
# 24          Tshopo  POLYGON ((23.59908 2.20184, 23.59396 2.19113, ...
# 25         Tshuapa  POLYGON ((22.12739 1.76262, 22.15742 1.76226, ...

# %%
# Ahora sí, se puede hacer el merge

# %%
# Se procesan los nombres
# Primero, se eliminarán los espacios
P_DRC['Provincia'] = P_DRC.Provincia.str.replace(' ','_')
Estadisticas_DRC['Provincia'] = Estadisticas_DRC.Provincia.str.replace(' ','_')
# Después, los guiones medios
P_DRC['Provincia'] = P_DRC.Provincia.str.replace('-','_')
Estadisticas_DRC['Provincia'] = Estadisticas_DRC.Provincia.str.replace('-','_')

# Después, se strippearán las columnas
Estadisticas_DRC = Estadisticas_DRC.rename(columns=lambda x: x.strip())
P_DRC = P_DRC.rename(columns=lambda x: x.strip())

# Después, se le aplica directamente el unidecode, porque los nombres en francés tienen carácteres que pueden ser molestos
import unidecode

byePunctuation=lambda x: unidecode.unidecode(x)
P_DRC[['Provincia']]=P_DRC[['Provincia']].map(byePunctuation)
Estadisticas_DRC[['Provincia']]=Estadisticas_DRC[['Provincia']].map(byePunctuation)

# Tratamos directamente con el fuzzy merge
# !pip install thefuzz
from thefuzz import process as fz
# Se crean sets con los  nombres
sP = set(P_DRC.Provincia)
sD = set(Estadisticas_DRC.Provincia)
# Ahora se calculan los coeficientes de igualdad
dMerge = [(f,fz.extractOne(f, sP)) for f in sorted(sD)]
dMerge, len(dMerge)
# Out:
# Requirement already satisfied: thefuzz in d:\anaconda\envs\geop2\lib\site-packages (0.20.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in d:\anaconda\envs\geop2\lib\site-packages (from thefuzz) (3.5.2)
# ([('Bas_Uele', ('Bas_Uele', 100)),
#   ('Equateur', ('Equateur', 100)),
#   ('Haut_Katanga', ('Haut_Katanga', 100)),
#   ('Haut_Lomami', ('Haut_Lomami', 100)),
#   ('Haut_Uele', ('Haut_Uele', 100)),
#   ('Ituri', ('Ituri', 100)),
#   ('Kasai', ('Kasai', 100)),
#   ('Kasai_Central', ('Kasai_Central', 100)),
#   ('Kasai_Oriental', ('Kasai_Oriental', 100)),
#   ('Kinshasa', ('Kinshasa', 100)),
#   ('Kongo_Central', ('Kongo_Central', 100)),
#   ('Kwango', ('Kwango', 100)),
#   ('Kwilu', ('Kwilu', 100)),
#   ('Lomami', ('Lomami', 100)),
#   ('Lualaba', ('Lualaba', 100)),
#   ('Mai_Ndombe', ('Mai_Ndombe', 100)),
#   ('Maniema', ('Maniema', 100)),
#   ('Mongala', ('Mongala', 100)),
#   ('Nord_Kivu', ('Nord_Kivu', 100)),
#   ('Nord_Ubangi', ('Nord_Ubangi', 100)),
#   ('Sankuru', ('Sankuru', 100)),
#   ('Sud_Kivu', ('Sud_Kivu', 100)),
#   ('Sud_Ubangi', ('Sud_Ubangi', 100)),
#   ('Tanganyika', ('Tanganyika', 100)),
#   ('Tshopo', ('Tshopo', 100)),
#   ('Tshuapa', ('Tshuapa', 100))],
#  26)

# %%
# Se mantuvo el número de filas?
len(dMerge) == len(P_DRC.Provincia)
# Out:
# True

# %%
# Ahora sí se procede con el merge
DRC_Datos = Estadisticas_DRC.merge(P_DRC, how='left')
# El número de filas terminó siendo igual?
len(DRC_Datos.Provincia) == len(P_DRC.Provincia)
# Out:
# True

# %%
# Parece que ya está mergeado de forma correcta, entonces
DRC_Datos
# Out:
#          Provincia  Esperanza_de_vida  Años_de_escolarización  \
# 0         Bas_Uele               56.1                     9.9
# 1         Equateur               61.2                    10.8
# 2     Haut_Katanga               56.7                    12.4
# 3      Haut_Lomami               53.9                     8.5
# 4        Haut_Uele               50.5                     8.5
# 5            Ituri               58.7                     6.8
# 6            Kasai               56.8                     9.4
# 7    Kasai_Central               53.3                    11.7
# 8   Kasai_Oriental               50.6                     9.5
# 9         Kinshasa               64.6                    13.7
# 10   Kongo_Central               67.7                    11.3
# 11          Kwango               51.5                    10.7
# 12           Kwilu               63.4                    13.3
# 13          Lomami               61.8                    11.3
# 14         Lualaba               58.2                     8.4
# 15      Mai_Ndombe               56.6                    11.8
# 16         Maniema               52.0                    11.8
# 17         Mongala               56.0                     8.4
# 18     Nord_Ubangi               57.7                    12.5
# 19       Nord_Kivu               59.5                    11.2
# 20         Sankuru               51.0                    11.9
# 21      Sud_Ubangi               51.6                    10.5
# 22        Sud_Kivu               62.5                     9.2
# 23      Tanganyika               53.4                     8.5
# 24          Tshopo               60.3                    11.3
# 25         Tshuapa               48.6                    10.6
#
#     Número_promedio_de_años_de_escolarización_en_adultos  \
# 0                                                 5.2
# 1                                                 7.6
# 2                                                10.0
# 3                                                 5.8
# 4                                                 5.8
# 5                                                 3.5
# 6                                                 6.1
# 7                                                 6.8
# 8                                                 6.9
# 9                                                11.2
# 10                                                7.5
# 11                                                5.2
# 12                                                8.4
# 13                                                6.3
# 14                                                5.8
# 15                                                6.8
# 16                                                6.4
# 17                                                5.4
# 18                                                5.8
# 19                                                8.4
# 20                                                6.8
# 21                                                5.2
# 22                                                7.6
# 23                                                5.3
# 24                                                7.2
# 25                                                5.6
#
#     Tasa_de_desempleo_2016                                           geometry
# 0                      0.3  POLYGON ((25.55505 5.37646, 25.56033 5.37533, ...
# 1                      1.3  POLYGON ((19.51188 2.02196, 19.60032 2.00518, ...
# 2                     11.1  POLYGON ((28.54810 -7.62268, 28.56232 -7.63546...
# 3                      2.3  POLYGON ((25.94890 -6.23409, 25.94897 -6.24754...
# 4                      3.2  POLYGON ((27.39413 5.09610, 27.41456 5.08784, ...
# 5                      1.7  POLYGON ((30.78596 3.64700, 30.78596 3.62100, ...
# 6                      0.1  POLYGON ((21.75535 -2.49128, 21.76883 -2.49800...
# 7                      2.0  POLYGON ((22.91916 -4.52640, 22.94181 -4.52706...
# 8                      2.0  POLYGON ((23.73511 -5.68923, 23.73781 -5.69317...
# 9                     11.4  POLYGON ((15.95045 -3.93047, 15.95131 -3.93136...
# 10                     2.0  POLYGON ((14.41276 -4.31460, 14.41882 -4.32696...
# 11                     0.4  POLYGON ((17.61221 -4.23314, 17.62396 -4.24320...
# 12                     2.1  POLYGON ((17.39747 -3.19806, 17.40001 -3.20150...
# 13                     0.5  POLYGON ((25.00325 -4.86532, 25.00509 -4.86703...
# 14                     1.3  POLYGON ((21.96284 -7.69976, 21.97001 -7.70335...
# 15                     0.7  POLYGON ((19.15473 -0.82204, 19.16991 -0.85066...
# 16                     1.8  POLYGON ((26.07762 -0.03658, 26.07949 -0.03686...
# 17                     0.1  POLYGON ((22.71572 3.12765, 22.72612 3.11883, ...
# 18                     0.6  POLYGON ((19.60200 5.13200, 19.61300 5.12800, ...
# 19                     8.2  POLYGON ((29.86257 0.95052, 29.86276 0.93075, ...
# 20                     2.1  POLYGON ((23.99545 -1.70136, 23.99908 -1.70323...
# 21                     0.3  POLYGON ((19.07291 4.77567, 19.07509 4.77141, ...
# 22                     2.7  POLYGON ((29.05073 -1.58385, 29.05140 -1.58395...
# 23                     0.9  POLYGON ((26.96836 -4.99952, 27.08852 -5.00293...
# 24                     0.9  POLYGON ((23.59908 2.20184, 23.59396 2.19113, ...
# 25                     0.6  POLYGON ((22.12739 1.76262, 22.15742 1.76226, ...

# %%
# Finalmente, nos aseguramos de que el resultado sea un gdf con el crc deseado
DRC_Datos= gpd.GeoDataFrame(DRC_Datos, crs = 4326)
DRC_Datos = DRC_Datos.to_crs(32734)
type(DRC_Datos)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#Todo bien!

# %% [markdown]
# ## Tarea 6
#
# Choose a numeric variable from your merged data.
#
# Decide which is the best classification scheme for that variable
# .
# Make a map for the best schem
# e.
# Make a histogram for the best scheme.

# %%
# Primero, hay que probar varios sistemas para los intervalos, según el método que se enseñó en clase
# El seaborn no parece ser necesario, pero igual lo estoy instalando en caso pueda faltar algo más adelante
# !pip install seaborn
import seaborn as sea
# !pip install numba
import mapclassify 
import numpy as np

np.random.seed(1234)
# Out:
# Requirement already satisfied: seaborn in d:\anaconda\envs\geop2\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\anaconda\envs\geop2\lib\site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in d:\anaconda\envs\geop2\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in d:\anaconda\envs\geop2\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\geop2\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Requirement already satisfied: numba in d:\anaconda\envs\geop2\lib\site-packages (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in d:\anaconda\envs\geop2\lib\site-packages (from numba) (0.41.1)
# Requirement already satisfied: numpy<1.27,>=1.22 in d:\anaconda\envs\geop2\lib\site-packages (from numba) (1.26.0)

# %%
# Se decide hacer 6 intervalos

K=6
Variable=DRC_Datos['Esperanza_de_vida']
ei6 = mapclassify.EqualInterval(Variable, k=K)
msd = mapclassify.StdMean(Variable)                             
q6=mapclassify.Quantiles(Variable,k=K)
mb6 = mapclassify.MaximumBreaks(Variable, k=K)
ht = mapclassify.HeadTailBreaks(Variable)
fj6 = mapclassify.FisherJenks(Variable, k=K)
jc6 = mapclassify.JenksCaspall(Variable, k=K)
mp6 = mapclassify.MaxP(Variable, k=K)

# %%
# Para comparar a las clasificaciones, se calcula la desviación absoluta media del parámetro (ADCM)
Clase = q6, ei6,msd, ht, mb6, fj6, jc6, mp6
Fits = np.array([ c.adcm for c in Clase])
ADCM = pd.DataFrame(Fits)
ADCM['Clasificador'] = [c.name for c in Clase]

ADCM.rename(columns = {0:'ADCM'},inplace=True)

ADCM
# Out:
#    ADCM    Clasificador
# 0  23.0       Quantiles
# 1  18.2   EqualInterval
# 2  39.2         StdMean
# 3  35.7  HeadTailBreaks
# 4  32.9   MaximumBreaks
# 5  16.4     FisherJenks
# 6  20.3    JenksCaspall
# 7  23.5            MaxP

# %%
# El ADCM del FisherJenks es el mínimo, así que se elige

# %%
# Se crea una columna con esto valores para el gdf 
DRC_Datos['EVida_FJ'] = fj6.yb
DRC_Datos
# Out:
#          Provincia  Esperanza_de_vida  Años_de_escolarización  \
# 0         Bas_Uele               56.1                     9.9
# 1         Equateur               61.2                    10.8
# 2     Haut_Katanga               56.7                    12.4
# 3      Haut_Lomami               53.9                     8.5
# 4        Haut_Uele               50.5                     8.5
# 5            Ituri               58.7                     6.8
# 6            Kasai               56.8                     9.4
# 7    Kasai_Central               53.3                    11.7
# 8   Kasai_Oriental               50.6                     9.5
# 9         Kinshasa               64.6                    13.7
# 10   Kongo_Central               67.7                    11.3
# 11          Kwango               51.5                    10.7
# 12           Kwilu               63.4                    13.3
# 13          Lomami               61.8                    11.3
# 14         Lualaba               58.2                     8.4
# 15      Mai_Ndombe               56.6                    11.8
# 16         Maniema               52.0                    11.8
# 17         Mongala               56.0                     8.4
# 18     Nord_Ubangi               57.7                    12.5
# 19       Nord_Kivu               59.5                    11.2
# 20         Sankuru               51.0                    11.9
# 21      Sud_Ubangi               51.6                    10.5
# 22        Sud_Kivu               62.5                     9.2
# 23      Tanganyika               53.4                     8.5
# 24          Tshopo               60.3                    11.3
# 25         Tshuapa               48.6                    10.6
#
#     Número_promedio_de_años_de_escolarización_en_adultos  \
# 0                                                 5.2
# 1                                                 7.6
# 2                                                10.0
# 3                                                 5.8
# 4                                                 5.8
# 5                                                 3.5
# 6                                                 6.1
# 7                                                 6.8
# 8                                                 6.9
# 9                                                11.2
# 10                                                7.5
# 11                                                5.2
# 12                                                8.4
# 13                                                6.3
# 14                                                5.8
# 15                                                6.8
# 16                                                6.4
# 17                                                5.4
# 18                                                5.8
# 19                                                8.4
# 20                                                6.8
# 21                                                5.2
# 22                                                7.6
# 23                                                5.3
# 24                                                7.2
# 25                                                5.6
#
#     Tasa_de_desempleo_2016                                           geometry  \
# 0                      0.3  POLYGON ((1005174.139 10596162.746, 1005762.21...
# 1                      1.3  POLYGON ((334493.735 10223563.902, 344329.518 ...
# 2                     11.1  POLYGON ((1334890.197 9150087.744, 1336446.305...
# 3                      2.3  POLYGON ((1048123.755 9308342.789, 1048117.583...
# 4                      3.2  POLYGON ((1210174.926 10566818.663, 1212463.04...
# 5                      1.7  POLYGON ((1592056.253 10409084.904, 1592088.13...
# 6                      0.1  POLYGON ((583975.122 9724613.012, 585473.061 9...
# 7                      2.0  POLYGON ((712932.929 9499404.379, 715446.097 9...
# 8                      2.0  POLYGON ((802973.914 9370431.302, 803270.895 9...
# 9                     11.4  POLYGON ((-61300.711 9563859.412, -61204.548 9...
# 10                     2.0  POLYGON ((-232539.039 9519919.345, -231850.343...
# 11                     0.4  POLYGON ((123826.716 9531280.885, 125138.101 9...
# 12                     2.1  POLYGON ((99484.640 9645811.454, 99768.716 964...
# 13                     0.5  POLYGON ((944226.038 9460904.706, 944429.544 9...
# 14                     1.3  POLYGON ((606184.942 9148773.880, 606975.615 9...
# 15                     0.7  POLYGON ((294652.660 9909092.711, 296344.727 9...
# 16                     1.8  POLYGON ((1065757.855 9995940.759, 1065966.797...
# 17                     0.1  POLYGON ((690663.230 10345858.087, 691820.745 ...
# 18                     0.6  POLYGON ((345041.829 10567424.526, 346260.396 ...
# 19                     8.2  POLYGON ((1490027.538 10106338.872, 1490054.48...
# 20                     2.1  POLYGON ((833324.967 9811688.669, 833729.282 9...
# 21                     0.3  POLYGON ((286262.108 10528166.452, 286502.978 ...
# 22                     2.7  POLYGON ((1398481.224 9823182.865, 1398556.320...
# 23                     0.9  POLYGON ((1162808.839 9444371.953, 1176198.591...
# 24                     0.9  POLYGON ((789099.495 10243623.087, 788531.953 ...
# 25                     0.6  POLYGON ((625399.442 10194860.722, 628739.643 ...
#
#     EVida_FJ
# 0          2
# 1          4
# 2          2
# 3          1
# 4          0
# 5          3
# 6          2
# 7          1
# 8          0
# 9          4
# 10         5
# 11         0
# 12         4
# 13         4
# 14         3
# 15         2
# 16         0
# 17         2
# 18         2
# 19         3
# 20         0
# 21         0
# 22         4
# 23         1
# 24         3
# 25         0

# %%
# Ahora, se grafica el mapa con las clasificaciones
import matplotlib.pyplot as plt
f, ax = plt.subplots(1, figsize=(9, 9))
DRC_Datos.plot(column='EVida_FJ', 
        cmap='viridis', 
        categorical=True,
        edgecolor='white', 
        linewidth=0., 
        alpha=0.75, 
        legend=True,
        legend_kwds=dict(loc=2),
        ax=ax
       )

ax.set_axis_off()

# %%
# Finalmente, se hace el histograma
fj6_bins=list(fj6.bins)
sea.histplot(DRC_Datos.Esperanza_de_vida, bins=fj6_bins, color='blue')
# Out:
# <Axes: xlabel='Esperanza_de_vida', ylabel='Count'>

# %% [markdown]
# ## Tarea 7
#
# Compute the neighbors of the capital of your country. Plot the results for each of the options.

# %%
# Ahora, como no se necesitan los datos numéricos que no se pudieron conseguir para los distritos,
# sí se puede trabajar con estos
Distritos_DRC = gpd.read_file(os.path.join("data","provincias_DRC","cod_admbnda_adm2_rgc_20190911.shp"))
Distritos_DRCs= gpd.GeoDataFrame(Distritos_DRC, crs = 4326)
Distritos_DRC = Distritos_DRC.to_crs(32734)

# Después, se procesan un poco los nombres de la columna de los distritos, para no tener problemas luego
Distritos_DRC['ADM2_FR'] = Distritos_DRC.ADM2_FR.str.replace(' ','_')
Distritos_DRC = Distritos_DRC.rename(columns=lambda x: x.strip())
import unidecode
byePunctuation=lambda x: unidecode.unidecode(x)
Distritos_DRC[['ADM2_FR']]=Distritos_DRC[['ADM2_FR']].map(byePunctuation)

# Finalmente, se revisa si es un gdf
type(Distritos_DRC)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Se instala el libsypal y se invoca a las funciones Queen, Rook y King (las tres opciones posibles para el cálculo)
# !pip install libpysal
from libpysal.weights import Queen, Rook, KNN
# Out:
# Requirement already satisfied: libpysal in d:\anaconda\envs\geop2\lib\site-packages (4.9.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (0.14.1)
# Requirement already satisfied: numpy>=1.22 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (1.26.0)
# Requirement already satisfied: packaging>=22 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (23.2)
# Requirement already satisfied: pandas>=1.4 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (2.1.3)
# Requirement already satisfied: platformdirs>=2.0.2 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (4.0.0)
# Requirement already satisfied: requests>=2.27 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (2.31.0)
# Requirement already satisfied: scipy>=1.8 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (1.11.3)
# Requirement already satisfied: shapely>=2.0.1 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\envs\geop2\lib\site-packages (from beautifulsoup4>=4.10->libpysal) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.10.0->libpysal) (1.9.5)
# Requirement already satisfied: pyproj>=3.3.0 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.10.0->libpysal) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.4->libpysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.4->libpysal) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.4->libpysal) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal) (2023.11.17)
# Requirement already satisfied: attrs>=19.2.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (23.1.0)
# Requirement already satisfied: click~=8.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (0.7.2)
# Requirement already satisfied: six in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (1.16.0)
# Requirement already satisfied: setuptools in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal) (68.2.2)
# Requirement already satisfied: colorama in d:\anaconda\envs\geop2\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.10.0->libpysal) (0.4.6)

# %%
# Ahora, se averigua cuál es la fila que contiene a la capital
Distritos_DRC.ADM2_FR.str.contains('Kinshasa').sort_values()
# Out:
# 0      False
# 121    False
# 122    False
# 123    False
# 124    False
#        ...
# 67     False
# 68     False
# 59     False
# 188    False
# 97      True
# Name: ADM2_FR, Length: 189, dtype: bool

# %%
# Es la 97!
Distritos_DRC.ADM2_FR[97]
# Out:
# 'Kinshasa'

# %%
# Primero el rook, con los vecinos en amarillo y Kinshasa (capital) en rojo
CDR_rook = Rook.from_dataframe(Distritos_DRC,use_index=False) 
# Se grafica
base=Distritos_DRC[Distritos_DRC.ADM2_FR=="Kinshasa"].plot()
Distritos_DRC.iloc[CDR_rook.neighbors[97] ,].plot(ax=base,facecolor="yellow",edgecolor='k')
Distritos_DRC.iloc[[97],:].plot(ax=base,facecolor="red")
# Out:
# <Axes: >

# %%
# Ahora con queen
CDR_queen = Queen.from_dataframe(Distritos_DRC,use_index=False)
base=Distritos_DRC[Distritos_DRC.ADM2_FR=="Kinshasa"].plot()
Distritos_DRC.iloc[CDR_queen.neighbors[97] ,].plot(ax=base,facecolor="yellow",edgecolor='k')
Distritos_DRC.iloc[[97],:].plot(ax=base,facecolor="red")
# Out:
# <Axes: >

# %%
# Finalmente, con king
CDR_knn = KNN.from_dataframe(Distritos_DRC, k=4)
base=Distritos_DRC[Distritos_DRC.ADM2_FR=="Kinshasa"].plot()
Distritos_DRC.iloc[CDR_knn.neighbors[97] ,].plot(ax=base,facecolor="yellow",edgecolor='k')
Distritos_DRC.iloc[[97],:].plot(ax=base,facecolor="red")
# Out:
# <Axes: >

# %%
# Se observa que para rook y queen es igual, mientras que para king se pierden algunos distritos. Esto se debe a que para knn
# se fija un número de vecinos y se elige a los 'k' más cercanos. Curiosamente, en knn se tuvo a una pequeña provincia extra en vez de las
# que estaban inmediatamente cerca. 
# Parece que para este caso, queen y rook son más fiables
# Como dato final, al norte de Kinshasa está el Rio Congo y su frontera con la República del Congo (No confundir con la República Democrática del Congo)
# por lo que es normal que no haya provincias vecinas hacia el norte

# %% [markdown]
# ## Tarea 8
#
# Compute the Moran's coefficient for all your numeric variables.
#
# Make a scatter plot for each variable.

# %%
# Se calcula el índice Moran para las variables numéricas. Ahora, lamentablemente de debe de volver a trabajar con provincias
# Primero, se instalan los paquetes
# !pip install esda
from esda.moran import Moran
# Out:
# Requirement already satisfied: esda in d:\anaconda\envs\geop2\lib\site-packages (2.5.1)
# Requirement already satisfied: libpysal in d:\anaconda\envs\geop2\lib\site-packages (from esda) (4.9.2)
# Requirement already satisfied: pandas>1.4 in d:\anaconda\envs\geop2\lib\site-packages (from esda) (2.1.3)
# Requirement already satisfied: scikit-learn>=1.0 in d:\anaconda\envs\geop2\lib\site-packages (from esda) (1.3.2)
# Requirement already satisfied: scipy>=1.9 in d:\anaconda\envs\geop2\lib\site-packages (from esda) (1.11.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>1.4->esda) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>1.4->esda) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>1.4->esda) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>1.4->esda) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\envs\geop2\lib\site-packages (from scikit-learn>=1.0->esda) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\geop2\lib\site-packages (from scikit-learn>=1.0->esda) (3.2.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->esda) (4.12.2)
# Requirement already satisfied: geopandas>=0.10.0 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->esda) (0.14.1)
# Requirement already satisfied: packaging>=22 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->esda) (23.2)
# Requirement already satisfied: platformdirs>=2.0.2 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->esda) (4.0.0)
# Requirement already satisfied: requests>=2.27 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->esda) (2.31.0)
# Requirement already satisfied: shapely>=2.0.1 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->esda) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\envs\geop2\lib\site-packages (from beautifulsoup4>=4.10->libpysal->esda) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.10.0->libpysal->esda) (1.9.5)
# Requirement already satisfied: pyproj>=3.3.0 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.10.0->libpysal->esda) (3.6.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\geop2\lib\site-packages (from python-dateutil>=2.8.2->pandas>1.4->esda) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->esda) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->esda) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->esda) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->esda) (2023.11.17)
# Requirement already satisfied: attrs>=19.2.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->esda) (23.1.0)
# Requirement already satisfied: click~=8.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->esda) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->esda) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->esda) (0.7.2)
# Requirement already satisfied: setuptools in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.10.0->libpysal->esda) (68.2.2)
# Requirement already satisfied: colorama in d:\anaconda\envs\geop2\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.10.0->libpysal->esda) (0.4.6)

# %%
# Se decide usar el rook para calcular el índice Moran
# Se tienen que calcular los rooks de nuevo, porque ahora se estará trabajando con provincias
CDRP_rook = Rook.from_dataframe(DRC_Datos,use_index=False)

# Esperanza de vida
moranEV = Moran(DRC_Datos['Esperanza_de_vida'], CDRP_rook)

# Tasa de desempleo
moranTD = Moran(DRC_Datos['Tasa_de_desempleo_2016'], CDRP_rook)

# Años de escolarización
moranAE = Moran(DRC_Datos['Años_de_escolarización'], CDRP_rook)

# Promedio de años de escolarización en adultos
moranAEP = Moran(DRC_Datos['Número_promedio_de_años_de_escolarización_en_adultos'], CDRP_rook)

# Finalmente, se determinan los coeficientes
moranEV.I, moranEV.p_sim, moranTD.I, moranTD.p_sim, moranAE.I, moranAE.p_sim, moranAEP.I, moranAEP.p_sim
# Out:
# (-0.0800018543844603,
#  0.395,
#  -0.0395008127565015,
#  0.407,
#  0.0233194664922541,
#  0.278,
#  -0.03395446785860578,
#  0.454)

# %%
# En todos los casos, el p-value es bastante alto, así que no se podría afirmar que exita clustering o no
# Sin embargo, un índice Moran positivo indicaría que hay clustering, mientras que uno negativo indicaría que hay scattering
# Probablemente, este p-value tan alto se deba a la poca cantidad de provincias. Si se hubiesen conseguido datos para los distritos,
# es posible que los resultados hayan sido mejores

# %%
# Se plotea para Esperanza de vida
# !pip install splot
from splot.esda import moran_scatterplot

fig, ax = moran_scatterplot(moranEV, aspect_equal=True)
ax.set_xlabel('EV_std')
ax.set_ylabel('SpatialLag_EV_std');
# Out:
# Requirement already satisfied: splot in d:\anaconda\envs\geop2\lib\site-packages (1.1.5.post1)
# Requirement already satisfied: esda in d:\anaconda\envs\geop2\lib\site-packages (from splot) (2.5.1)
# Requirement already satisfied: geopandas>=0.4.0 in d:\anaconda\envs\geop2\lib\site-packages (from splot) (0.14.1)
# Requirement already satisfied: giddy in d:\anaconda\envs\geop2\lib\site-packages (from splot) (2.3.4)
# Requirement already satisfied: libpysal in d:\anaconda\envs\geop2\lib\site-packages (from splot) (4.9.2)
# Requirement already satisfied: mapclassify in d:\anaconda\envs\geop2\lib\site-packages (from splot) (2.6.1)
# Requirement already satisfied: matplotlib in d:\anaconda\envs\geop2\lib\site-packages (from splot) (3.8.2)
# Requirement already satisfied: numpy in d:\anaconda\envs\geop2\lib\site-packages (from splot) (1.26.0)
# Requirement already satisfied: seaborn in d:\anaconda\envs\geop2\lib\site-packages (from splot) (0.13.0)
# Requirement already satisfied: spreg in d:\anaconda\envs\geop2\lib\site-packages (from splot) (1.4.2)
# Requirement already satisfied: fiona>=1.8.21 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.4.0->splot) (1.9.5)
# Requirement already satisfied: packaging in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.4.0->splot) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.4.0->splot) (2.1.3)
# Requirement already satisfied: pyproj>=3.3.0 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.4.0->splot) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in d:\anaconda\envs\geop2\lib\site-packages (from geopandas>=0.4.0->splot) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0 in d:\anaconda\envs\geop2\lib\site-packages (from esda->splot) (1.3.2)
# Requirement already satisfied: scipy>=1.9 in d:\anaconda\envs\geop2\lib\site-packages (from esda->splot) (1.11.3)
# Requirement already satisfied: quantecon>=0.4.7 in d:\anaconda\envs\geop2\lib\site-packages (from giddy->splot) (0.7.1)
# Requirement already satisfied: beautifulsoup4>=4.10 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->splot) (4.12.2)
# Requirement already satisfied: platformdirs>=2.0.2 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->splot) (4.0.0)
# Requirement already satisfied: requests>=2.27 in d:\anaconda\envs\geop2\lib\site-packages (from libpysal->splot) (2.31.0)
# Requirement already satisfied: networkx>=2.7 in d:\anaconda\envs\geop2\lib\site-packages (from mapclassify->splot) (3.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (1.4.5)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\geop2\lib\site-packages (from matplotlib->splot) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\envs\geop2\lib\site-packages (from beautifulsoup4>=4.10->libpysal->splot) (2.5)
# Requirement already satisfied: attrs>=19.2.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (23.1.0)
# Requirement already satisfied: certifi in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (2023.11.17)
# Requirement already satisfied: click~=8.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (0.7.2)
# Requirement already satisfied: six in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (1.16.0)
# Requirement already satisfied: setuptools in d:\anaconda\envs\geop2\lib\site-packages (from fiona>=1.8.21->geopandas>=0.4.0->splot) (68.2.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.4.0->geopandas>=0.4.0->splot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\envs\geop2\lib\site-packages (from pandas>=1.4.0->geopandas>=0.4.0->splot) (2023.3)
# Requirement already satisfied: numba>=0.49.0 in d:\anaconda\envs\geop2\lib\site-packages (from quantecon>=0.4.7->giddy->splot) (0.58.1)
# Requirement already satisfied: sympy in d:\anaconda\envs\geop2\lib\site-packages (from quantecon>=0.4.7->giddy->splot) (1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->splot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->splot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\geop2\lib\site-packages (from requests>=2.27->libpysal->splot) (2.1.0)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\envs\geop2\lib\site-packages (from scikit-learn>=1.0->esda->splot) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\envs\geop2\lib\site-packages (from scikit-learn>=1.0->esda->splot) (3.2.0)
# Requirement already satisfied: colorama in d:\anaconda\envs\geop2\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.4.0->splot) (0.4.6)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in d:\anaconda\envs\geop2\lib\site-packages (from numba>=0.49.0->quantecon>=0.4.7->giddy->splot) (0.41.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda\envs\geop2\lib\site-packages (from sympy->quantecon>=0.4.7->giddy->splot) (1.3.0)

# %%
# Tasa de desempleo
fig, ax = moran_scatterplot(moranTD, aspect_equal=True)
ax.set_xlabel('TD_std')
ax.set_ylabel('SpatialLag_TD_std');

# %%
# Años de escolarización
fig, ax = moran_scatterplot(moranAE, aspect_equal=True)
ax.set_xlabel('AE_std')
ax.set_ylabel('SpatialLag_AE_std');

# %%
# Años de escolarización promedio en adultos
fig, ax = moran_scatterplot(moranEV, aspect_equal=True)
ax.set_xlabel('AEP_std')
ax.set_ylabel('SpatialLag_AEP_std');

# %%
# Los scatter plots tampoco se ven muy bien, pero esto coincide con los p-values altos que se observaron

# %% [markdown]
# ## Tarea 9
#
# Compute the Local Moran for the variables in your data that have significant spatial correlation.
#
# Create a new column for each of those variables, with a label ('0 no_sig', '1 hotSpot', '2 coldOutlier', '3 coldSpot', '4 hotOutlier').
#
# Prepare a map for each of the variables analyzed, showing the spots and outliers.

# %%
# En mi caso, ningún parámetro tuvo buena correlación espacial para las provincias. Sin embargo, se hará este trabajo para
# los datos de esperanza de vida y de años de escolarización promedio, que fueron los que presentaron los p-values más bajos

# %%
# Se calculan los Local Moran
from esda.moran import Moran_Local

IMLEV = Moran_Local(y=DRC_Datos['Esperanza_de_vida'], w=CDRP_rook,seed=2250)
IMLAEP = Moran_Local(y=DRC_Datos['Número_promedio_de_años_de_escolarización_en_adultos'], w=CDRP_rook,seed=2250)

IMLEV.p_sim, IMLAEP.p_sim
# Out:
# (array([0.417, 0.077, 0.327, 0.38 , 0.303, 0.466, 0.072, 0.278, 0.307,
#         0.075, 0.287, 0.004, 0.339, 0.016, 0.448, 0.154, 0.255, 0.318,
#         0.228, 0.223, 0.094, 0.32 , 0.314, 0.389, 0.041, 0.498]),
#  array([0.208, 0.11 , 0.12 , 0.379, 0.044, 0.297, 0.483, 0.375, 0.458,
#         0.206, 0.103, 0.023, 0.167, 0.242, 0.222, 0.044, 0.288, 0.152,
#         0.035, 0.321, 0.411, 0.353, 0.377, 0.201, 0.056, 0.491]))

# %%
# Se evalúa la significancia para cada provincia, pero se aumentará un poco el margen del p-value, para compensar la
# falta de clustering en nuestros datos
DRC_Datos['EV_quadrant']=[l if p <0.08 else 0 for l,p in zip(IMLEV.q,IMLEV.p_sim)  ]

DRC_Datos['AEP_quadrant']=[l if p <0.08 else 0 for l,p in zip(IMLAEP.q,IMLAEP.p_sim)  ]

# Se cuentan
DRC_Datos['EV_quadrant'].value_counts(),DRC_Datos['AEP_quadrant'].value_counts()
# Out:
# (EV_quadrant
#  0    20
#  4     4
#  1     1
#  2     1
#  Name: count, dtype: int64,
#  AEP_quadrant
#  0    21
#  3     2
#  2     1
#  1     1
#  4     1
#  Name: count, dtype: int64)

# %%
# Se crean columnas para las variables de la esperanza de vida y se cuentan los casos
labels = [ '0 no_sig', '1 hotSpot', '2 coldOutlier', '3 coldSpot', '4 hotOutlier']

DRC_Datos['EV_quadrant_names']=[labels[i] for i in DRC_Datos['EV_quadrant']]
DRC_Datos['EV_quadrant_names'].value_counts()
# Out:
# EV_quadrant_names
# 0 no_sig         20
# 4 hotOutlier      4
# 1 hotSpot         1
# 2 coldOutlier     1
# Name: count, dtype: int64

# %%
# Se crean columnas para las variables de los años de escolarización promedio y se cuentan los casos
labels = [ '0 no_sig', '1 hotSpot', '2 coldOutlier', '3 coldSpot', '4 hotOutlier']

DRC_Datos['AEP_quadrant_names']=[labels[i] for i in DRC_Datos['AEP_quadrant']]
DRC_Datos['AEP_quadrant_names'].value_counts()
# Out:
# AEP_quadrant_names
# 0 no_sig         21
# 3 coldSpot        2
# 2 coldOutlier     1
# 1 hotSpot         1
# 4 hotOutlier      1
# Name: count, dtype: int64

# %%
# Finalmente, se grafica

# %%
# Primero, la esperanza de vida
from matplotlib import colors
myColMap = colors.ListedColormap([ 'seashell', 'salmon', 'green', 'lime','red'])
f, ax = plt.subplots(1, figsize=(12,12))
plt.title('Spots and Outliers')

DRC_Datos.plot(column='EV_quadrant_names', 
                categorical=True,
                cmap=myColMap,
                linewidth=0.1, 
                edgecolor='k',
                legend=True,
                legend_kwds={'loc': 'center left', 
                             'bbox_to_anchor': (0.7, 0.6)},
                ax=ax)
ax.set_axis_off()
plt.show()

# %%
# Después, los años de escolarización promedio en adultos
from matplotlib import colors
myColMap = colors.ListedColormap([ 'seashell', 'salmon', 'green', 'lime','red'])
f, ax = plt.subplots(1, figsize=(12,12))
plt.title('Spots and Outliers')

DRC_Datos.plot(column='AEP_quadrant_names', 
                categorical=True,
                cmap=myColMap,
                linewidth=0.1, 
                edgecolor='k',
                legend=True,
                legend_kwds={'loc': 'center left', 
                             'bbox_to_anchor': (0.7, 0.6)},
                ax=ax)
ax.set_axis_off()
plt.show()

# %%
#Fin!
#pd: Gracias por el curso, lo disfruté bastante
